# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Liver\OneDrive\Desktop\MAHDI\pandas_course\Datasets\spotify_history.csv")

# %%
df.head()
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# ...

# %%
df.groupby("artist_name").artist_name.count()
# Out:
# artist_name
# "Weird Al" Yankovic          2
# & Friends                    1
# *NSYNC                       2
# .Sinh                        1
# 070 Shake                    2
#                             ..
# Örjan Hultén Orion           2
# ゼロ戦                          6
# 岸正之                          2
# 石橋和子                         2
# 落日飛車 Sunset Rollercoaster    8
# Name: artist_name, Length: 4113, dtype: int64

# %%
df_review = df.groupby(['artist_name', 'track_name']).agg([len])

# %%
df_review
# Out:
#                                                                              spotify_track_uri  \
#                                                                                            len
# artist_name               track_name
# "Weird Al" Yankovic       Bob                                                                1
#                           Ringtone                                                           1
# & Friends                 Driving                                                            1
# *NSYNC                    Bye Bye Bye - From Deadpool and Wolverine Sound...                 1
#                           Merry Christmas, Happy Holidays                                    1
# ...                                                                                        ...
# 岸正之                       Modern Museum                                                      2
# ...

# %%
v = df_review.index
type(v)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
df_review.reset_index
# Out:
# <bound method DataFrame.reset_index of                                                                              spotify_track_uri  \
#                                                                                            len
# artist_name               track_name
# "Weird Al" Yankovic       Bob                                                                1
#                           Ringtone                                                           1
# & Friends                 Driving                                                            1
# *NSYNC                    Bye Bye Bye - From Deadpool and Wolverine Sound...                 1
#                           Merry Christmas, Happy Holidays                                    1
# ...                                                                                        ...
# 岸正之                       Modern Museum                                                      2
# ...

# %%
df_review.sort_values
# Out:
# <bound method DataFrame.sort_values of                                                                              spotify_track_uri  \
#                                                                                            len
# artist_name               track_name
# "Weird Al" Yankovic       Bob                                                                1
#                           Ringtone                                                           1
# & Friends                 Driving                                                            1
# *NSYNC                    Bye Bye Bye - From Deadpool and Wolverine Sound...                 1
#                           Merry Christmas, Happy Holidays                                    1
# ...                                                                                        ...
# 岸正之                       Modern Museum                                                      2
# ...

# %%
df_review.sort_index
# Out:
# <bound method DataFrame.sort_index of                                                                              spotify_track_uri  \
#                                                                                            len
# artist_name               track_name
# "Weird Al" Yankovic       Bob                                                                1
#                           Ringtone                                                           1
# & Friends                 Driving                                                            1
# *NSYNC                    Bye Bye Bye - From Deadpool and Wolverine Sound...                 1
#                           Merry Christmas, Happy Holidays                                    1
# ...                                                                                        ...
# 岸正之                       Modern Museum                                                      2
# ...
