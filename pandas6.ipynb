# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Liver\OneDrive\Desktop\MAHDI\pandas_course\Datasets\airlines_flights_data.csv")

df2 = pd.read_csv(r"C:\Users\Liver\OneDrive\Desktop\MAHDI\pandas_course\Datasets\spotify_history.csv")

# %%
df1.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df2.head()
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# ...

# %%
df3 = pd.concat([df1, df2])

# %%
df3
# Out:
#         index   airline   flight source_city departure_time stops  \
# 0         0.0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1         1.0  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2         2.0   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3         3.0   Vistara   UK-995       Delhi        Morning  zero
# 4         4.0   Vistara   UK-963       Delhi        Morning  zero
# ...       ...       ...      ...         ...            ...   ...
# 149855    NaN       NaN      NaN         NaN            NaN   NaN
# 149856    NaN       NaN      NaN         NaN            NaN   NaN
# 149857    NaN       NaN      NaN         NaN            NaN   NaN
# 149858    NaN       NaN      NaN         NaN            NaN   NaN
# 149859    NaN       NaN      NaN         NaN            NaN   NaN
#
#          arrival_time destination_city    class  duration  ...  \
# 0               Night           Mumbai  Economy      2.17  ...
# ...

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
# Empty DataFrame
# Columns: [index, airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price, spotify_track_uri, ts, platform, ms_played, track_name, artist_name, album_name, reason_start, reason_end, shuffle, skipped]
# Index: []
#
# [0 rows x 23 columns]
