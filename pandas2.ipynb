# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Liver\OneDrive\Desktop\MAHDI\pandas_course\Datasets\airlines_flights_data.csv")

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.price
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
df.source_city
# Out:
# 0           Delhi
# 1           Delhi
# 2           Delhi
# 3           Delhi
# 4           Delhi
#            ...
# 300148    Chennai
# 300149    Chennai
# 300150    Chennai
# 300151    Chennai
# 300152    Chennai
# Name: source_city, Length: 300153, dtype: object

# %%
df['airline']
# Out:
# 0         SpiceJet
# 1         SpiceJet
# 2          AirAsia
# 3          Vistara
# 4          Vistara
#             ...
# 300148     Vistara
# 300149     Vistara
# 300150     Vistara
# 300151     Vistara
# 300152     Vistara
# Name: airline, Length: 300153, dtype: object

# %%
df['flight'][0]
# Out:
# 'SG-8709'

# %%
df.iloc[0]
# Out:
# index                      0
# airline             SpiceJet
# flight               SG-8709
# source_city            Delhi
# departure_time       Evening
# stops                   zero
# arrival_time           Night
# destination_city      Mumbai
# class                Economy
# duration                2.17
# days_left                  1
# price                   5953
# Name: 0, dtype: object

# %%
df.iloc[:, 0]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 300148    300148
# 300149    300149
# 300150    300150
# 300151    300151
# 300152    300152
# Name: index, Length: 300153, dtype: int64

# %%
df.iloc[:3, 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: index, dtype: int64

# %%
df.iloc[1:3, 0]
# Out:
# 1    1
# 2    2
# Name: index, dtype: int64

# %%
df.loc[0, ['source_city', 'price', 'destination_city']]
# Out:
# source_city          Delhi
# price                 5953
# destination_city    Mumbai
# Name: 0, dtype: object

# %%
df.set_index("price")
# Out:
#         index   airline   flight source_city departure_time stops  \
# price
# 5953        0  SpiceJet  SG-8709       Delhi        Evening  zero
# 5953        1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 5956        2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 5955        3   Vistara   UK-995       Delhi        Morning  zero
# 5955        4   Vistara   UK-963       Delhi        Morning  zero
# ...       ...       ...      ...         ...            ...   ...
# 69265  300148   Vistara   UK-822     Chennai        Morning   one
# 77105  300149   Vistara   UK-826     Chennai      Afternoon   one
# 79099  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 81585  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 81585  300152   Vistara   UK-822     Chennai        Morning   one
#
#         arrival_time destination_city     class  duration  days_left
# price
# 5953           Night           Mumbai   Economy      2.17          1
# ...

# %%
df.set_index('airline', inplace=True)

# %%
df
# Out:
#            index   flight source_city departure_time stops   arrival_time  \
# airline
# SpiceJet       0  SG-8709       Delhi        Evening  zero          Night
# SpiceJet       1  SG-8157       Delhi  Early_Morning  zero        Morning
# AirAsia        2   I5-764       Delhi  Early_Morning  zero  Early_Morning
# Vistara        3   UK-995       Delhi        Morning  zero      Afternoon
# Vistara        4   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# Vistara   300148   UK-822     Chennai        Morning   one        Evening
# Vistara   300149   UK-826     Chennai      Afternoon   one          Night
# Vistara   300150   UK-832     Chennai  Early_Morning   one          Night
# Vistara   300151   UK-828     Chennai  Early_Morning   one        Evening
# Vistara   300152   UK-822     Chennai        Morning   one        Evening
#
#          destination_city     class  duration  days_left  price
# ...

# %%
df.loc[(df.source_city == "Delhi") & (df.destination_city == "Mumbai")]
# Out:
#             index   flight source_city departure_time stops   arrival_time  \
# airline
# SpiceJet        0  SG-8709       Delhi        Evening  zero          Night
# SpiceJet        1  SG-8157       Delhi  Early_Morning  zero        Morning
# AirAsia         2   I5-764       Delhi  Early_Morning  zero  Early_Morning
# Vistara         3   UK-995       Delhi        Morning  zero      Afternoon
# Vistara         4   UK-963       Delhi        Morning  zero        Morning
# ...           ...      ...         ...            ...   ...            ...
# Air_India  211968   AI-401       Delhi  Early_Morning   one          Night
# Air_India  211969   AI-762       Delhi          Night   one          Night
# Vistara    211970   UK-747       Delhi  Early_Morning   one      Afternoon
# Vistara    211971   UK-747       Delhi  Early_Morning   one          Night
# Vistara    211972   UK-707       Delhi        Evening   one          Night
#
# ...
